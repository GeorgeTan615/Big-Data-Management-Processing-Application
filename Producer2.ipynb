# %% [markdown]
# # FIT3182 Major Assignment Part B Task 1b (Event Producer 2)
# ## George Tan Juan Sheng (30884128)
# ### Part B Task 1b
# #### Write a python program that loads all the data from hotspot_AQUA_streaming.csv and randomly (with replacement) feed the data to the stream every 2 seconds. AQUA is the satellite from NASA that reports latitude, longitude, confidence and surface temperature of a location. You will need to append additional information such as producer information to identify the producer and created date & time.

# %% [markdown]
# First, we have to connect to our MongoClient and access the collection we have made from Part A (so that we can get the latest date).

# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from datetime import datetime,timedelta

client = MongoClient () 
db = client.fit3182_assignment_db
collection = db.partA

# %% [markdown]
# Then, we would have to write our program so that we would be able to feed our data to Kafka.

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random

# Reads data from hotspot_AQUA_streaming.csv, puts each row data into a document and appends all such documents into a list.
def read_hotspot_AQUA_streaming():
    hotspot_AQUA_streaming = pd.read_csv('hotspot_AQUA_streaming.csv')

    data = []
    for index,aquaRow in hotspot_AQUA_streaming.iterrows():
        document = {}
        document['latitude'] = float(aquaRow['latitude'])
        document['longitude'] = float(aquaRow['longitude'])
        document['confidence'] = int(aquaRow['confidence'])
        document['surface_temperature_celcius'] = int(aquaRow['surface_temperature_celcius'])
        data.append(document)
    
    return data

# Gets the latest date in our collection
def get_latest_date():
    latest_date = collection.aggregate([
                {"$sort":{"date":-1}},
                {"$project":{"_id":0,"date":1}},
                {"$limit":1}
                ])
    for document in latest_date:
        latest_date = document['date']
    return latest_date
     
# Publishes message to Kafka
def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, value=data)
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'PartB'
    print('Publishing records..')
    producer02 = connect_kafka_producer()
    data = read_hotspot_AQUA_streaming()  # Gets all the documents produced from hotspot_AQUA_streaming.csv
    latest_date = get_latest_date() + timedelta(days=1) # After getting latest date, we would add one day to it to get the first date we would use to start feeding data
    secondsPassed= 0 # Tracks how many seconds we should add to our latest date

    while True:
        chosenData = random.choice(data)  # Randomly chooses a document from our list of documents
        curr_date = latest_date + timedelta(seconds=secondsPassed) # Creates the date we will use to feed our data by adding the number of seconds to our latest date from Part A
        chosenData['producer'] = "hotspot_AQUA_streaming"
        chosenData["created_datetime"] = curr_date.strftime("%d/%m/%Y %H:%M:%S")
        publish_message(producer02, topic, chosenData)
        secondsPassed += 17280 # After we insert a hotspot streaming data, add 17280 seconds to secondPassed. 17280 second is equivalent to 24 hours divided by 5. As we would insert 5 hotspot AQUA streaming data per day, adding 17280 seconds each time after we insert a hotspot streaming data simulates the time difference of adding the 5 data in a day
        sleep(2) # Sleep for 2 seconds so that we would be able to insert 5 data per climate streaming data being inserted, as climate streaming data is inserted every 10 seconds
# Out:
# Publishing records..
# Message published successfully. Data: {'latitude': -36.7076, 'longitude': 142.5982, 'confidence': 73, 'surface_temperature_celcius': 47, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.7587, 'longitude': 142.8521, 'confidence': 84, 'surface_temperature_celcius': 80, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.6498, 'longitude': 142.5997, 'confidence': 92, 'surface_temperature_celcius': 70, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.8431, 'longitude': 147.5395, 'confidence': 68, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -37.9255, 'longitude': 143.1236, 'confidence': 68, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.5642, 'longitude': 142.5943, 'confidence': 51, 'surface_temperature_celcius': 38, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.3635, 'longitude': 142.2809, 'confidence': 91, 'surface_temperature_celcius': 68, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.8717, 'longitude': 143.3652, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.3072, 'longitude': 147.5003, 'confidence': 58, 'surface_temperature_celcius': 46, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.1964, 'longitude': 144.5217, 'confidence': 93, 'surface_temperature_celcius': 72, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.5553, 'longitude': 143.0672, 'confidence': 78, 'surface_temperature_celcius': 53, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.6543, 'longitude': 142.91, 'confidence': 86, 'surface_temperature_celcius': 61, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.7038, 'longitude': 141.8813, 'confidence': 70, 'surface_temperature_celcius': 45, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.46, 'longitude': 148.102, 'confidence': 88, 'surface_temperature_celcius': 65, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.2394, 'longitude': 143.628, 'confidence': 73, 'surface_temperature_celcius': 47, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.2185, 'longitude': 147.4402, 'confidence': 100, 'surface_temperature_celcius': 106, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '04/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -38.1748, 'longitude': 143.0552, 'confidence': 69, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '04/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.3551, 'longitude': 141.0343, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '04/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.3883, 'longitude': 143.7526, 'confidence': 56, 'surface_temperature_celcius': 39, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '04/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.8147, 'longitude': 142.8375, 'confidence': 74, 'surface_temperature_celcius': 48, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '04/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -38.0605, 'longitude': 143.6358, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '05/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.174, 'longitude': 142.737, 'confidence': 79, 'surface_temperature_celcius': 52, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '05/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.4857, 'longitude': 143.5322, 'confidence': 58, 'surface_temperature_celcius': 40, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '05/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.6158, 'longitude': 145.4424, 'confidence': 100, 'surface_temperature_celcius': 101, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '05/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.993, 'longitude': 141.2317, 'confidence': 67, 'surface_temperature_celcius': 43, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '05/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.61, 'longitude': 149.296, 'confidence': 81, 'surface_temperature_celcius': 56, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '06/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.1744, 'longitude': 143.9256, 'confidence': 63, 'surface_temperature_celcius': 43, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '06/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.369, 'longitude': 143.7132, 'confidence': 97, 'surface_temperature_celcius': 80, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '06/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.5005, 'longitude': 143.1305, 'confidence': 79, 'surface_temperature_celcius': 52, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '06/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.5125, 'longitude': 144.4496, 'confidence': 87, 'surface_temperature_celcius': 62, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '06/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.5915, 'longitude': 143.0015, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '07/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -35.9498, 'longitude': 145.6229, 'confidence': 54, 'surface_temperature_celcius': 41, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '07/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.2948, 'longitude': 141.3486, 'confidence': 98, 'surface_temperature_celcius': 82, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '07/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.9158, 'longitude': 141.9147, 'confidence': 61, 'surface_temperature_celcius': 41, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '07/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -38.0765, 'longitude': 143.9516, 'confidence': 79, 'surface_temperature_celcius': 53, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '07/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.6217, 'longitude': 142.0944, 'confidence': 55, 'surface_temperature_celcius': 39, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '08/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.2212, 'longitude': 143.1666, 'confidence': 76, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '08/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.4149, 'longitude': 141.0156, 'confidence': 85, 'surface_temperature_celcius': 60, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '08/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.926, 'longitude': 144.0898, 'confidence': 85, 'surface_temperature_celcius': 59, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '08/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -35.891999999999996, 'longitude': 145.62, 'confidence': 71, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '08/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -35.8182, 'longitude': 143.8739, 'confidence': 100, 'surface_temperature_celcius': 92, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '09/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.5012, 'longitude': 142.5853, 'confidence': 100, 'surface_temperature_celcius': 90, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '09/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.0411, 'longitude': 141.7071, 'confidence': 69, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '09/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.0856, 'longitude': 144.233, 'confidence': 73, 'surface_temperature_celcius': 47, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '09/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -37.4007, 'longitude': 142.7674, 'confidence': 69, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '09/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -38.1693, 'longitude': 143.0466, 'confidence': 93, 'surface_temperature_celcius': 73, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '10/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.6662, 'longitude': 142.9874, 'confidence': 64, 'surface_temperature_celcius': 42, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '10/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.8922, 'longitude': 145.1252, 'confidence': 60, 'surface_temperature_celcius': 40, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '10/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.5738, 'longitude': 142.3038, 'confidence': 100, 'surface_temperature_celcius': 101, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '10/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.827, 'longitude': 142.5446, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '10/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -38.0812, 'longitude': 143.2335, 'confidence': 80, 'surface_temperature_celcius': 54, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '11/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.6281, 'longitude': 142.4349, 'confidence': 64, 'surface_temperature_celcius': 68, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '11/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.5107, 'longitude': 144.4722, 'confidence': 84, 'surface_temperature_celcius': 58, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '11/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.9243, 'longitude': 144.1064, 'confidence': 74, 'surface_temperature_celcius': 48, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '11/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -35.4407, 'longitude': 142.3644, 'confidence': 57, 'surface_temperature_celcius': 35, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '11/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.0899, 'longitude': 141.0238, 'confidence': 100, 'surface_temperature_celcius': 90, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '12/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.3933, 'longitude': 144.1287, 'confidence': 87, 'surface_temperature_celcius': 63, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '12/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.3636, 'longitude': 141.3622, 'confidence': 83, 'surface_temperature_celcius': 57, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '12/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.7927, 'longitude': 143.0658, 'confidence': 85, 'surface_temperature_celcius': 59, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '12/01/2022 14:24:00'}
