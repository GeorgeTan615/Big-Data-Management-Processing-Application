# %% [markdown]
# # FIT3182 Major Assignment Part B Task 1c (Event Producer 3)
# ## George Tan Juan Sheng (30884128)
# ### Part B Task 1c
# #### Write a python program that loads all the data from hotspot_TERRA_streaming.csv and randomly (with replacement) feeds the data to the stream every 2 seconds. TERRA is another satellite from NASA that reports 4 latitude, longitude, confidence and surface temperature of a location. You will need to append additional information such as producer information to identify the producer and created date & time.

# %% [markdown]
# First, we have to connect to our MongoClient and access the collection we have made from Part A (so that we can get the latest date).

# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from datetime import datetime,timedelta

client = MongoClient () 
db = client.fit3182_assignment_db
collection = db.partA

# %% [markdown]
# Then, we would have to write our program so that we would be able to feed our data to Kafka.

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random

# Reads data from hotspot_TERRA_streaming.csv, puts each row data into a document and appends all such documents into a list.
def read_hotspot_TERRA_streaming():
    hotspot_TERRA_streaming = pd.read_csv('hotspot_TERRA_streaming.csv')

    data = []
    for index,terraRow in hotspot_TERRA_streaming.iterrows():
        document = {}
        document['latitude'] = float(terraRow['latitude'])
        document['longitude'] = float(terraRow['longitude'])
        document['confidence'] = int(terraRow['confidence'])
        document['surface_temperature_celcius'] = int(terraRow['surface_temperature_celcius'])
        data.append(document)
    
    return data

# Gets the latest date in our collection
def get_latest_date():
    latest_date = collection.aggregate([
                {"$sort":{"date":-1}},
                {"$project":{"_id":0,"date":1}},
                {"$limit":1}
                ])
    for document in latest_date:
        latest_date = document['date']
    return latest_date
    
# Publishes message to Kafka
def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, value=data)
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'PartB'
    print('Publishing records..')
    producer03 = connect_kafka_producer()
    data = read_hotspot_TERRA_streaming() # Gets all the documents produced from hotspot_TERRA_streaming.csv
    latest_date = get_latest_date() + timedelta(days=1) # After getting latest date, we would add one day to it to get the first date we would use to start feeding data
    secondsPassed= 0 # Tracks how many seconds we should add to our latest date

    while True:
        chosenData = random.choice(data)   # Randomly chooses a document from our list of documents
        curr_date = latest_date + timedelta(seconds=secondsPassed) # Creates the date we will use to feed our data by adding the number of seconds to our latest date from Part A
        chosenData['producer'] = "hotspot_TERRA_streaming"
        chosenData["created_datetime"] = curr_date.strftime("%d/%m/%Y %H:%M:%S")
        publish_message(producer03, topic, chosenData)
        secondsPassed += 17280 # After we insert a hotspot streaming data, add 17280 seconds to secondPassed. 17280 second is equivalent to 24 hours divided by 5. As we would insert 5 hotspot AQUA streaming data per day, adding 17280 seconds each time after we insert a hotspot streaming data simulates the time difference of adding the 5 data in a day
        sleep(2) # Sleep for 2 seconds so that we would be able to insert 5 data per climate streaming data being inserted, as climate streaming data is inserted every 10 seconds
# Out:
# Publishing records..
# Message published successfully. Data: {'latitude': -36.4624, 'longitude': 141.0446, 'confidence': 78, 'surface_temperature_celcius': 51, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -38.1185, 'longitude': 143.9514, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.5052, 'longitude': 142.8636, 'confidence': 62, 'surface_temperature_celcius': 54, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.45, 'longitude': 148.097, 'confidence': 70, 'surface_temperature_celcius': 37, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -38.116, 'longitude': 143.81799999999998, 'confidence': 76, 'surface_temperature_celcius': 43, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.7893, 'longitude': 142.7953, 'confidence': 58, 'surface_temperature_celcius': 40, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -35.1145, 'longitude': 141.2627, 'confidence': 76, 'surface_temperature_celcius': 49, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -35.4439, 'longitude': 143.2005, 'confidence': 74, 'surface_temperature_celcius': 54, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.3296, 'longitude': 141.7522, 'confidence': 63, 'surface_temperature_celcius': 41, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -38.0505, 'longitude': 142.4791, 'confidence': 57, 'surface_temperature_celcius': 40, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.1346, 'longitude': 145.2196, 'confidence': 92, 'surface_temperature_celcius': 71, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.5949, 'longitude': 142.6857, 'confidence': 100, 'surface_temperature_celcius': 98, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.9378, 'longitude': 142.541, 'confidence': 55, 'surface_temperature_celcius': 39, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.9647, 'longitude': 142.1729, 'confidence': 74, 'surface_temperature_celcius': 48, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.8616, 'longitude': 142.8025, 'confidence': 90, 'surface_temperature_celcius': 78, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.749, 'longitude': 148.297, 'confidence': 50, 'surface_temperature_celcius': 42, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '04/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.8377, 'longitude': 143.4624, 'confidence': 64, 'surface_temperature_celcius': 42, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '04/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -38.231, 'longitude': 147.172, 'confidence': 83, 'surface_temperature_celcius': 60, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '04/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -36.7988, 'longitude': 141.3436, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '04/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -37.5158, 'longitude': 142.8257, 'confidence': 64, 'surface_temperature_celcius': 42, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '04/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.579, 'longitude': 144.1483, 'confidence': 55, 'surface_temperature_celcius': 39, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '05/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.6516, 'longitude': 141.4943, 'confidence': 74, 'surface_temperature_celcius': 48, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '05/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.2044, 'longitude': 145.7706, 'confidence': 58, 'surface_temperature_celcius': 51, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '05/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.0669, 'longitude': 141.0556, 'confidence': 97, 'surface_temperature_celcius': 80, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '05/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.7179, 'longitude': 142.2536, 'confidence': 70, 'surface_temperature_celcius': 45, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '05/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -38.3525, 'longitude': 147.0408, 'confidence': 72, 'surface_temperature_celcius': 56, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '06/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.3326, 'longitude': 142.8706, 'confidence': 74, 'surface_temperature_celcius': 47, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '06/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.7303, 'longitude': 142.9382, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '06/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.903, 'longitude': 145.25, 'confidence': 53, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '06/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.1337, 'longitude': 146.1243, 'confidence': 61, 'surface_temperature_celcius': 41, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '06/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.3089, 'longitude': 146.1139, 'confidence': 74, 'surface_temperature_celcius': 48, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '07/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.8932, 'longitude': 142.3395, 'confidence': 72, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '07/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.8545, 'longitude': 142.5132, 'confidence': 100, 'surface_temperature_celcius': 115, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '07/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.7361, 'longitude': 145.335, 'confidence': 79, 'surface_temperature_celcius': 52, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '07/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.1556, 'longitude': 141.5904, 'confidence': 89, 'surface_temperature_celcius': 65, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '07/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.1484, 'longitude': 141.3879, 'confidence': 70, 'surface_temperature_celcius': 48, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '08/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.8297, 'longitude': 142.4083, 'confidence': 72, 'surface_temperature_celcius': 48, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '08/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -36.7842, 'longitude': 146.9658, 'confidence': 53, 'surface_temperature_celcius': 39, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '08/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.9796, 'longitude': 146.8024, 'confidence': 62, 'surface_temperature_celcius': 41, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '08/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.86, 'longitude': 142.8137, 'confidence': 66, 'surface_temperature_celcius': 45, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '08/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.564, 'longitude': 147.99200000000002, 'confidence': 74, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '09/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.0902, 'longitude': 143.8394, 'confidence': 65, 'surface_temperature_celcius': 42, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '09/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -35.6138, 'longitude': 143.8666, 'confidence': 91, 'surface_temperature_celcius': 68, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '09/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.8565, 'longitude': 147.2532, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '09/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.9299, 'longitude': 142.9671, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '09/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -36.8142, 'longitude': 142.8947, 'confidence': 86, 'surface_temperature_celcius': 60, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '10/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -37.6865, 'longitude': 148.5154, 'confidence': 66, 'surface_temperature_celcius': 50, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '10/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -37.3942, 'longitude': 147.0455, 'confidence': 60, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '10/01/2022 09:36:00'}
# Message published successfully. Data: {'latitude': -37.7767, 'longitude': 141.8127, 'confidence': 68, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '10/01/2022 14:24:00'}
# Message published successfully. Data: {'latitude': -36.3757, 'longitude': 145.5589, 'confidence': 65, 'surface_temperature_celcius': 43, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '10/01/2022 19:12:00'}
# Message published successfully. Data: {'latitude': -37.9029, 'longitude': 143.5946, 'confidence': 73, 'surface_temperature_celcius': 47, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '11/01/2022 00:00:00'}
# Message published successfully. Data: {'latitude': -36.8237, 'longitude': 141.4881, 'confidence': 84, 'surface_temperature_celcius': 58, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '11/01/2022 04:48:00'}
# Message published successfully. Data: {'latitude': -38.0189, 'longitude': 143.6406, 'confidence': 68, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '11/01/2022 09:36:00'}
